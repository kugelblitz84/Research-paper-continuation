# %% [markdown]
# # Block-A: 35-cell status and validation aggregation
#
# Read-only by default. No dataset, GPU, training or inference is needed. Test/oracle results never enter selection. Registry-only completion is labelled; missing endpoint validation is not replaced by a task mean.

# %%
REBUILD_INDEX = False
SEED = 42

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
if not (ROOT / "src").is_dir():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from src.results_registry import matrix_status, rebuild
from src.block_a import aggregate
status = rebuild(seed=SEED) if REBUILD_INDEX else matrix_status(seed=SEED)
display(status.pivot(index="backbone", columns="system_code", values="status"))
display(status)

# %%
matrix, summary, selection = aggregate(status)
display(matrix)
display(summary)
display(selection)

# %% [markdown]
# `REBUILD_INDEX=True` updates derived CSV/JSON indexes from canonical artifacts only. It never trains or evaluates. H3/H4 contain two independent networks each: 35 system cells represent 49 network instances if every cell is trained independently. Existing H1 retains its third auxiliary task; this distinction must accompany any comparison.
